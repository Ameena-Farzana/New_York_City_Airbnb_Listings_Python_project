# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id
# 0          2539                 Clean & quiet apt home by the park      2787  \
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Data Exploration

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.head()
# Out:
#      id                                              name  host_id
# 0  2539                Clean & quiet apt home by the park     2787  \
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude
# 0         John            Brooklyn    Kensington  40.64749  -73.97237  \
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review
# ...

# %%
df.tail()
# Out:
#              id                                               name   host_id
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441  \
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853  \
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000  \
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month
# count    48895.000000       48895.000000       38843.000000  \
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
# Check datatypes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Change the datatype of last_review to datetime

df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ##### Find the null values

# %%
df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood
# 0      False  False    False      False                False          False  \
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Treat the null values with appropriate values

df['name'].fillna("Unknown_Name" , inplace = True)
df['host_name'].fillna("Unknown_Host", inplace = True)
df['last_review'].fillna("0", inplace = True)
df['reviews_per_month'].fillna("0.0", inplace = True)

# %%
df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.head()
# Out:
#      id                                              name  host_id
# 0  2539                Clean & quiet apt home by the park     2787  \
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude
# 0         John            Brooklyn    Kensington  40.64749  -73.97237  \
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews
# 0     Private room    149               1                  9  \
# ...

# %% [markdown]
# ##### Find the duplicate values

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# ##### drop the irrelevant columns.
#     'id', 'Host_name', 'last_review' are irrelevant datas in the dataset.

# %%
df.drop(['id', 'host_name', 'last_review'], axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#                                  name  host_id neighbourhood_group
# 0  Clean & quiet apt home by the park     2787            Brooklyn  \
# 1               Skylit Midtown Castle     2845           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights
# 0    Kensington  40.64749  -73.97237     Private room    149               1  \
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
#
#    number_of_reviews reviews_per_month  calculated_host_listings_count
# 0                  9              0.21                               6  \
# 1                 45              0.38                               2
#
#    availability_365
# 0               365
# 1               355

# %% [markdown]
# ##### Check the unique values

# %%
df.nunique()
# Out:
# name                              47906
# host_id                           37457
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# reviews_per_month                   938
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df['name'].unique()
# Out:
# array(['Clean & quiet apt home by the park', 'Skylit Midtown Castle',
#        'THE VILLAGE OF HARLEM....NEW YORK !', ...,
#        'Sunny Studio at Historical Neighborhood',
#        '43rd St. Time Square-cozy single bed',
#        "Trendy duplex in the very heart of Hell's Kitchen"], dtype=object)

# %%
df['host_id'].unique()
# Out:
# array([     2787,      2845,      4632, ..., 274321313,  23492952,
#         68119814])

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df['neighbourhood'].unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
df['latitude'].unique()
# Out:
# array([40.64749, 40.75362, 40.80902, ..., 40.80953, 40.70184, 40.81475])

# %%
df['longitude'].unique()
# Out:
# array([-73.97237, -73.98377, -73.9419 , ..., -73.87727, -73.93614,
#        -73.80844])

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df['price'].unique()
# Out:
# array([  149,   225,   150,    89,    80,   200,    60,    79,   135,
#           85,   120,   140,   215,    99,   190,   299,   130,   110,
#           44,   180,    50,    52,    55,    70,    35,    40,    68,
#          115,   151,   228,   144,    69,    49,   375,   250,   275,
#          230,    51,    65,   105,    95,   145,   285,    94,   800,
#          131,    98,   100,   125,   175,   500,   101,   220,    59,
#          350,   199,   325,   235,   170,   400,    75,    90,   185,
#           77,    76,   160,   195,   156,   219,   475,   165,   196,
#           83,   123,   265,   249,   121,    45,    71,    64,   159,
#          189,   239,   305,   155,    92,    36,    37,   205,    39,
#          390,   129,   212,   124,   122,   109,   575,   229,   169,
#          113,   179,   349,   139,   650,    67,   599,   211,   290,
#           87,   395,   260,    97,   132,   141,   495,   259,    96,
# ...

# %%
df['minimum_nights'].unique()
# Out:
# array([   1,    3,   10,   45,    2,    5,    4,   90,    7,   14,   60,
#          29,   30,  180,    9,   31,    6,   15,    8,   26,   28,  200,
#          50,   17,   21,   11,   25,   13,   35,   27,   18,   20,   40,
#          44,   65,   55,  120,  365,  122,   19,  240,   88,  115,  150,
#         370,   16,   80,  181,  265,  300,   59,  185,  360,   56,   12,
#          70,   39,   24,   32, 1000,  110,  270,   22,   75,  250,   62,
#          23, 1250,  364,   74,  198,  100,  500,   43,   91,  480,   53,
#          99,  160,   47,  999,  186,  366,   68,   93,   87,  183,  299,
#         175,   98,  133,  354,   42,   33,   37,  225,  400,  105,  184,
#         153,  134,  222,   58,  210,  275,  182,  114,   85,   36])

# %%
df['number_of_reviews'].unique()
# Out:
# array([  9,  45,   0, 270,  74,  49, 430, 118, 160,  53, 188, 167, 113,
#         27, 148, 198, 260, 130,  39,  71,  88,  19,  58, 108,  29, 242,
#        197, 273, 168, 231, 214, 245,  15,  25,  81,  97,  11, 248,  61,
#        135, 112,  73,  82, 328, 105, 289, 138,  21,  42,   5,  66, 143,
#        191,   4, 338, 106, 190,  23, 142,  54,  70,  16,  94, 194,   2,
#        174,  24, 166,   1,  30, 139, 233,  68,  46, 335, 162, 170, 334,
#         12, 467,   7,  38, 324, 115, 354, 195,  13,  36,  63, 155, 193,
#         32,  50,  26, 426, 227,  84,   3,  10, 124, 240, 200,  79,  34,
#        134, 126, 234, 202,  28, 309,  14,  80, 294, 150,  47, 219, 114,
#        213,  86,  18, 206, 122,  33,  52,  51, 199,  41, 109, 151, 285,
#        375,   6, 358, 226, 104, 204, 253, 129,  37,  69, 192,  17, 222,
#        205, 458, 183, 189, 127,  35, 171,  92, 238,  56, 111, 147, 177,
#        185,  62, 181, 333, 441, 279, 203, 210,  64, 132,  20,  67, 187,
# ...

# %%
df['reviews_per_month'].unique()
# Out:
# array([0.21, 0.38, '0.0', 4.64, 0.1, 0.59, 0.4, 3.47, 0.99, 1.33, 0.43,
#        1.5, 1.34, 0.91, 0.22, 1.2, 1.72, 2.12, 4.44, 0.07, 1.09, 0.37,
#        0.61, 0.73, 1.37, 0.49, 1.11, 0.24, 2.04, 1.42, 1.65, 2.37, 0.66,
#        1.41, 1.96, 1.81, 2.08, 0.39, 0.23, 0.69, 0.84, 2.25, 0.52, 1.16,
#        1.01, 0.63, 0.7, 2.82, 0.9, 0.17, 2.49, 1.19, 0.3, 0.12, 0.57,
#        0.16, 4.72, 1.4, 1.26, 1.64, 1.6, 0.92, 0.2, 1.28, 0.54, 0.62,
#        0.15, 0.53, 1.73, 0.05, 1.54, 0.28, 3.4, 1.57, 1.05, 0.71, 0.11,
#        0.27, 1.23, 0.87, 2.09, 0.6, 0.55, 3.02, 0.79, 1.46, 1.61, 3.0,
#        0.13, 4.22, 0.06, 3.01, 3.2, 2.03, 0.08, 0.19, 0.33, 0.58, 2.35,
#        1.86, 0.29, 0.45, 0.25, 0.02, 3.89, 0.77, 0.03, 0.04, 0.01, 2.19,
#        0.74, 0.09, 0.32, 1.24, 2.6, 0.26, 2.86, 2.17, 1.66, 0.94, 1.78,
#        0.78, 1.06, 2.0, 0.8, 0.75, 0.36, 1.79, 1.92, 1.18, 0.5, 1.17,
#        0.48, 1.85, 1.04, 1.43, 2.69, 3.52, 0.31, 3.44, 1.0, 1.45, 3.04,
# ...

# %%
df['calculated_host_listings_count'].unique()
# Out:
# array([  6,   2,   1,   4,   3,   5,   7,  13,  28,  11,   8,   9,  52,
#         18,  15,  19,  10,  39,  26,  29,  12,  21,  96,  14,  34,  43,
#        121,  37,  49,  31,  91,  16,  87,  33,  23,  50,  20,  25, 232,
#         17,  47, 103,  65,  30,  27, 327,  32])

# %%
df['availability_365'].unique()
# Out:
# array([365, 355, 194,   0, 129, 220, 188,   6,  39, 314, 333,  46, 321,
#         12,  21, 249, 347, 364, 304, 233,  85,  75, 311,  67, 255, 284,
#        359, 269, 340,  22,  96, 345, 273, 309,  95, 215, 265, 192, 251,
#        302, 140, 234, 257,  30, 301, 294, 320, 154, 263, 180, 231, 297,
#        292, 191,  72, 362, 336, 116,  88, 224, 322, 324, 132, 295, 238,
#        209, 328,  38,   7, 272,  26, 288, 317, 207, 185, 158,   9, 198,
#        219, 342, 312, 243, 152, 137, 222, 346, 208, 279, 250, 164, 298,
#        260, 107, 199, 299,  20, 318, 216, 245, 189, 307, 310, 213, 278,
#         16, 178, 275, 163,  34, 280,   1, 170, 214, 248, 262, 339,  10,
#        290, 230,  53, 126,   3,  37, 353, 177, 246, 225,  18, 343, 326,
#        162, 240, 363, 247, 323, 125,  91, 286,  60,  58, 351, 201, 232,
#        258, 341, 244, 329, 253, 348,   2,  56,  68, 360,  76,  15, 226,
#        349,  11, 316, 281, 287,  14,  86, 261, 331,  51, 254, 103,  42,
# ...

# %% [markdown]
# ### Data Analysis and Visualization

# %%
df.head()
# Out:
#                                                name  host_id
# 0                Clean & quiet apt home by the park     2787  \
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room  \
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews reviews_per_month
# 0    149               1                  9              0.21  \
# ...

# %% [markdown]
# ### Find the most listing host Id on Airbnb platform and who taking the advantages of this services

# %%
top_hostId = df.host_id.value_counts().head(10)
top_hostId
# Out:
# host_id
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
# 12243051      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: count, dtype: int64

# %%
df['calculated_host_listings_count'].describe()
# Out:
# count    48895.000000
# mean         7.143982
# std         32.952519
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        327.000000
# Name: calculated_host_listings_count, dtype: float64

# %% [markdown]
# ##### plot bar chart for top host_ids

# %%
plt.figure(figsize = (15,8))

sns.barplot(x = top_hostId.index, y = top_hostId.values, palette = "Greens")

plt.title("Host with most listing in NYC")
plt.xlabel("Host IDs")
plt.ylabel("Listing Counts")
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# There is a good distribution between top 10 hosts within the listing and the id '219517861' has 321 listing.

# %% [markdown]
# ###  Exploring Neighborhood Distribution in New York City's Boroughs

# %%
df.neighbourhood_group.value_counts()
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                name  host_id
# 0                Clean & quiet apt home by the park     2787  \
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room  \
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews reviews_per_month
# 0    149               1                  9              0.21  \
# ...

# %%
df['price'].describe(percentiles=[.01,.25, .75, .85,.95,.98,.99,1])
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 1%          30.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# 85%        225.000000
# 95%        355.000000
# 98%        550.000000
# 99%        799.000000
# 100%     10000.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# ##### Here the outlier of 10000 presented. so remove the value and take the 550 as the price range for better visualization

# %%
#creating a sub-dataframe with no extreme values / less than 550

data = df[df.price < 550]

data.head(3)
# Out:
#                                   name  host_id neighbourhood_group
# 0   Clean & quiet apt home by the park     2787            Brooklyn  \
# 1                Skylit Midtown Castle     2845           Manhattan
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights
# 0    Kensington  40.64749  -73.97237     Private room    149               1  \
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
#
#    number_of_reviews reviews_per_month  calculated_host_listings_count
# 0                  9              0.21                               6  \
# 1                 45              0.38                               2
# 2                  0               0.0                               1
#
#    availability_365
# 0               365
# 1               355
# 2               365

# %% [markdown]
# #### Violinplot to showcase distribtuion of prices in neighbourhood groups

# %%
plt.figure(figsize = (10,8))

sns.violinplot(data = data, x = 'neighbourhood_group', y = 'price')

plt.title('Distribution of prices for each neighberhood_group')
plt.xlabel("Neighbourhood_Groups")
plt.ylabel("price")

plt.show()

# %% [markdown]
# #### Observations
# ######      * Manhattan has the highest range of prices for the listings with 150 price as average observation and Brooklyn with 90 per night.
# ######      * Queens and Staten Island appear to have very similar distributions, Bronx is the cheapest of them all.
# ######      * Manhattan is one of the most expensive places in the world to live in, where Bronx appears to have lower standards of living.

# %% [markdown]
# ### Top 10 Neighborhoods with the Highest Number of Airbnb Listings

# %%
# Find out the top 10 neighbourhoods

neighbours = df[['neighbourhood','neighbourhood_group']].value_counts()

neighbours.head(10)
# Out:
# neighbourhood       neighbourhood_group
# Williamsburg        Brooklyn               3920
# Bedford-Stuyvesant  Brooklyn               3714
# Harlem              Manhattan              2658
# Bushwick            Brooklyn               2465
# Upper West Side     Manhattan              1971
# Hell's Kitchen      Manhattan              1958
# East Village        Manhattan              1853
# Upper East Side     Manhattan              1798
# Crown Heights       Brooklyn               1564
# Midtown             Manhattan              1545
# Name: count, dtype: int64

# %%
neighbour_df = df.loc[df['neighbourhood'].isin(['Williamsburg','Bedford-Stuyvesant','Harlem','Bushwick',
                 'Upper West Side','Hell\'s Kitchen','East Village','Upper East Side','Crown Heights','Midtown'])]

neighbour_df
# Out:
#                                                     name   host_id
# 1                                  Skylit Midtown Castle      2845  \
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 6                                        BlissArtsSpace!      7356
# 7                       Large Furnished Room Near B'way       8967
# 8                     Cozy Clean Guest Room - Family Apt      7490
# ...                                                  ...       ...
# 48890    Charming one bedroom - newly renovated rowhouse   8232441
# 48891      Affordable room in Bushwick/East Williamsburg   6570630
# 48892            Sunny Studio at Historical Neighborhood  23492952
# 48893               43rd St. Time Square-cozy single bed  30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#       neighbourhood_group       neighbourhood  latitude  longitude
# 1               Manhattan             Midtown  40.75362  -73.98377  \
# ...

# %% [markdown]
# #### Countplot for Top 10 neighbourhoods

# %%
plt.figure(figsize = (18, 12))

sns.countplot(x ='neighbourhood', hue = 'neighbourhood_group', data = neighbour_df, palette = "Blues")

plt.title("Top 10 Neighborhood by Airbnb Listing")
plt.xlabel("Neighborhoods")
plt.ylabel("Count")

plt.legend(title = "Borough")
plt.xticks(rotation = 45, size = 12)
plt.xticks(rotation = 90, size = 12)

plt.show()

# %% [markdown]
# #### Observations :
# ###### * Manhattan and Brooklyn are one of the most traveled destinations, therefore would have the most listing availability.
# ###### * Bedford-Stuyvesant and Williamsburg are the most popular for Manhattan borough, and Harlem for Brooklyn.

# %% [markdown]
# ### Distribution of different room types

# %%
room_df = df.room_type.value_counts()

room_df
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10, 8))

plt.pie(room_df.values, labels = room_df.index, autopct='%1.1f%%',  startangle = 120, explode = [0.02,0.02,0.02])

plt.title("Distribution of room_type")
plt.show()

# %% [markdown]
# #### Observations:
# ###### * The dataset mainly consists of 2 types of rooms : Entire homes/aprt, which make up the majority of listing 53.1 % and private rooms, accounting fri 46.7% of the listings
# ###### * Shared rooms are the least prevalent, comprising only 2.4%.

# %% [markdown]
# ### Most listing roomtypes with neighbourhood

# %%
df[['neighbourhood', 'room_type']]
# Out:
#             neighbourhood        room_type
# 0              Kensington     Private room
# 1                 Midtown  Entire home/apt
# 2                  Harlem     Private room
# 3            Clinton Hill  Entire home/apt
# 4             East Harlem  Entire home/apt
# ...                   ...              ...
# 48890  Bedford-Stuyvesant     Private room
# 48891            Bushwick     Private room
# 48892              Harlem  Entire home/apt
# 48893      Hell's Kitchen      Shared room
# 48894      Hell's Kitchen     Private room
#
# [48895 rows x 2 columns]

# %%
df[['neighbourhood', 'room_type']].sort_values(by = 'room_type', ascending = True)
# Out:
#             neighbourhood        room_type
# 41474  Financial District  Entire home/apt
# 20248           Chinatown  Entire home/apt
# 39530        West Village  Entire home/apt
# 39531  Bedford-Stuyvesant  Entire home/apt
# 20243        Williamsburg  Entire home/apt
# ...                   ...              ...
# 16786        Williamsburg      Shared room
# 11348       East New York      Shared room
# 16777  Bedford-Stuyvesant      Shared room
# 43878              Corona      Shared room
# 5155              Astoria      Shared room
#
# [48895 rows x 2 columns]

# %% [markdown]
# ##### Countplot for distribution of room types across neighborhoods

# %%
plt.figure(figsize =(12, 8))

sns.countplot(x ='neighbourhood', hue ='room_type', data = neighbour_df, palette = ['#FF5733','#3498DB','#98FB98'])

plt.title("Listing Room Type Distribution by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Count")

plt.legend(title = "Room Type")
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# #### Observations :
# ###### * The presence of 'Shared room' type Airbnb listings is notably minimal within the top 10 neighborhoods with the highest listing densities.
# ###### * Majority of listings in the top 10 neighborhoods are dominated by 'Entire home/apt' and 'Private room' types.
# ###### * This suggests that travelers and hosts in these neighborhoods prefer the privacy and convenience offered by entire homes or private rooms over shared accommodations.

# %% [markdown]
# ### Analyzing the neighbourhood using wordcloud

# %%
# Import libraries

from wordcloud import WordCloud

# %%
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.neighbourhood))
plt.imshow(wordcloud)
plt.axis('off')
plt.title("Keywords for neighbourhoods ", size = 43)

plt.show()

# %% [markdown]
# ### Price Distribution

# %%
plt.figure(figsize = (10, 7))

sns.boxplot(y = df['price'])

plt.title("Price Distribution")
plt.show()

# %% [markdown]
# ### Mapping Airbnb Listing Prices: Exploring Price Distribution Based on Latitude and Longitude

# %% [markdown]
# #### Create a scatter plot fro price based on Latitude and Longitude

# %%
plt.figure(figsize =(27, 18))

plt.scatter(x ='longitude', y ='latitude', data = df)

plt.title('Geospatial Visualization of Airbnb Listings')
plt.xlabel('Longitude', size = 25)
plt.ylabel('Latitude', size = 25)

plt.xticks(size = 20)
plt.yticks(size = 20)
plt.show()

# %%
df.head(3)
# Out:
#                                   name  host_id neighbourhood_group
# 0   Clean & quiet apt home by the park     2787            Brooklyn  \
# 1                Skylit Midtown Castle     2845           Manhattan
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights
# 0    Kensington  40.64749  -73.97237     Private room    149               1  \
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
#
#    number_of_reviews reviews_per_month  calculated_host_listings_count
# 0                  9              0.21                               6  \
# 1                 45              0.38                               2
# 2                  0               0.0                               1
#
#    availability_365
# 0               365
# 1               355
# 2               365

# %% [markdown]
# ###  Top 10 reviewed listings in NYC

# %%
review_df = df.sort_values(by = 'number_of_reviews', ascending = False)

# %%
review_df.head()
# Out:
#                                  name   host_id neighbourhood_group
# 11759         Room near JFK Queen Bed  47621202              Queens  \
# 2031       Great Bedroom in Manhattan   4734398           Manhattan
# 2030   Beautiful Bedroom in Manhattan   4734398           Manhattan
# 2015     Private Bedroom in Manhattan   4734398           Manhattan
# 13495         Room Near JFK Twin Beds  47621202              Queens
#
#       neighbourhood  latitude  longitude     room_type  price  minimum_nights
# 11759       Jamaica  40.66730  -73.76831  Private room     47               1  \
# 2031         Harlem  40.82085  -73.94025  Private room     49               1
# 2030         Harlem  40.82124  -73.93838  Private room     49               1
# 2015         Harlem  40.82264  -73.94041  Private room     49               1
# 13495       Jamaica  40.66939  -73.76975  Private room     47               1
#
#        number_of_reviews reviews_per_month  calculated_host_listings_count
# ...

# %%
top10_review_df = review_df[['name', 'number_of_reviews']].head(10)

top10_review_df
# Out:
#                                                     name  number_of_reviews
# 11759                            Room near JFK Queen Bed                629
# 2031                          Great Bedroom in Manhattan                607
# 2030                      Beautiful Bedroom in Manhattan                597
# 2015                        Private Bedroom in Manhattan                594
# 13495                            Room Near JFK Twin Beds                576
# 10623                  Steps away from Laguardia airport                543
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !                540
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE                510
# 4870                  Private brownstone studio Brooklyn                488
# 471                      LG Private Room/Family Friendly                480

# %% [markdown]
# #### Observations :
# ###### * The listing "Room near JFK Queen Bed" received an impressive 629 reviews, making it one of the most sought-after options for travelers.
# ###### * "Great Bedroom in Manhattan" comes in close second with 607 reviews, indicating its popularity among visitors to the city.

# %% [markdown]
# ### 8) Average Price spend in top 10 NYC

# %%
review_df['price']
# Out:
# 11759     47
# 2031      49
# 2030      49
# 2015      49
# 13495     47
#         ...
# 12724    250
# 12721    175
# 12717     45
# 12716    100
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
top_price = review_df['price'].head(10)
top_price
# Out:
# 11759     47
# 2031      49
# 2030      49
# 2015      49
# 13495     47
# 10623     46
# 1879      99
# 20403     48
# 4870     160
# 471       60
# Name: price, dtype: int64

# %%
print("The average price for top 10 reviewed list : ")

top_price.mean()
# Out:
# The average price for top 10 reviewed list :
# 65.4

# %% [markdown]
# ### Correlation between Variables

# %%
df.head()
# Out:
#                                                name  host_id
# 0                Clean & quiet apt home by the park     2787  \
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room  \
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews reviews_per_month
# 0    149               1                  9              0.21  \
# ...

# %%
num_column = df.select_dtypes(exclude = object)

num_column.head(2)
# Out:
#    host_id  latitude  longitude  price  minimum_nights  number_of_reviews
# 0     2787  40.64749  -73.97237    149               1                  9  \
# 1     2845  40.75362  -73.98377    225               1                 45
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
# Find the correlation between numeric columns

corr = num_column.corr()

corr
# Out:
#                                  host_id  latitude  longitude     price
# host_id                         1.000000  0.020224   0.127055  0.015309  \
# latitude                        0.020224  1.000000   0.084788  0.033939
# longitude                       0.127055  0.084788   1.000000 -0.150019
# price                           0.015309  0.033939  -0.150019  1.000000
# minimum_nights                 -0.017364  0.024869  -0.062747  0.042799
# number_of_reviews              -0.140106 -0.015389   0.059094 -0.047954
# calculated_host_listings_count  0.154950  0.019517  -0.114713  0.057472
# availability_365                0.203492 -0.010983   0.082731  0.081829
#
#                                 minimum_nights  number_of_reviews
# host_id                              -0.017364          -0.140106  \
# latitude                              0.024869          -0.015389
# longitude                            -0.062747           0.059094
# ...

# %%
plt.figure(figsize=(15,8))

sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###  Rooms available in different neighborhoods

# %% [markdown]
# #### Box plot to show the relationship

# %%
df[['neighbourhood_group','availability_365']].sort_values(by = "neighbourhood_group", ascending = False)
# Out:
#       neighbourhood_group  availability_365
# 16714       Staten Island                83
# 36368       Staten Island               177
# 27234       Staten Island               319
# 42103       Staten Island                85
# 37607       Staten Island               262
# ...                   ...               ...
# 23750               Bronx                87
# 36535               Bronx                 0
# 43510               Bronx                 0
# 47565               Bronx                35
# 21642               Bronx               134
#
# [48895 rows x 2 columns]

# %%
df.groupby('neighbourhood_group')['availability_365'].sum()
# Out:
# neighbourhood_group
# Bronx             180843
# Brooklyn         2015070
# Manhattan        2425586
# Queens            818464
# Staten Island      74480
# Name: availability_365, dtype: int64

# %% [markdown]
# #### Boxplot for the relationship

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=df, x='neighbourhood_group', y='availability_365', palette='BuGn')

plt.title("Relationship between Neighborhood Group and Room Availability")
plt.xlabel("Neighborhood Group")
plt.ylabel("Availability (Days)")

plt.show()

# %%
df.head(2)
# Out:
#                                  name  host_id neighbourhood_group
# 0  Clean & quiet apt home by the park     2787            Brooklyn  \
# 1               Skylit Midtown Castle     2845           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights
# 0    Kensington  40.64749  -73.97237     Private room    149               1  \
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
#
#    number_of_reviews reviews_per_month  calculated_host_listings_count
# 0                  9              0.21                               6  \
# 1                 45              0.38                               2
#
#    availability_365
# 0               365
# 1               355

# %% [markdown]
# ### Average number of nights spend in different room types

# %% [markdown]
# #### Distribution for Minimum nights

# %%
plt.figure(figsize = (10,7))

sns.boxplot(y = df["minimum_nights"])

plt.title("Distribution of Minimum Nights")
plt.show()

# %%
night_df = df.groupby('room_type')['minimum_nights'].mean()

night_df
# Out:
# room_type
# Entire home/apt    8.506907
# Private room       5.377900
# Shared room        6.475000
# Name: minimum_nights, dtype: float64

# %%
plt.figure(figsize = (10, 6))
sns.barplot(x = night_df.index, y = night_df.values, palette ='Reds')
plt.title("Comparison of Minimum Nights for Different Room Types")
plt.xlabel("Room Type")
plt.ylabel("Minimum Nights")
plt.show()

# %% [markdown]
# ###  No of reviews received from each neighbourhood

# %%
df[['neighbourhood_group', 'number_of_reviews']]
# Out:
#       neighbourhood_group  number_of_reviews
# 0                Brooklyn                  9
# 1               Manhattan                 45
# 2               Manhattan                  0
# 3                Brooklyn                270
# 4               Manhattan                  9
# ...                   ...                ...
# 48890            Brooklyn                  0
# 48891            Brooklyn                  0
# 48892           Manhattan                  0
# 48893           Manhattan                  0
# 48894           Manhattan                  0
#
# [48895 rows x 2 columns]

# %%
no_review_df = df.groupby('neighbourhood_group')['number_of_reviews'].sum()

no_review_df
# Out:
# neighbourhood_group
# Bronx             28371
# Brooklyn         486574
# Manhattan        454569
# Queens           156950
# Staten Island     11541
# Name: number_of_reviews, dtype: int64

# %%
sns.barplot(x = no_review_df.index, y = no_review_df.values, palette = 'Purples')

plt.xlabel("neighbourhood_group")
plt.ylabel("number_of_reviews")
plt.show()

# %% [markdown]
# ### Number of reviews vs Price

# %%
df[['number_of_reviews', 'price']]
# Out:
#        number_of_reviews  price
# 0                      9    149
# 1                     45    225
# 2                      0    150
# 3                    270     89
# 4                      9     80
# ...                  ...    ...
# 48890                  0     70
# 48891                  0     40
# 48892                  0    115
# 48893                  0     55
# 48894                  0     90
#
# [48895 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))

sns.violinplot(x='number_of_reviews', y='price', data=df, palette='coolwarm')
plt.title("Distribution of Price vs. Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Price")

plt.show()

# %% [markdown]
# ### Analyze the listed properties Using Wordcloud

# %%
df.head(2)
# Out:
#                                  name  host_id neighbourhood_group
# 0  Clean & quiet apt home by the park     2787            Brooklyn  \
# 1               Skylit Midtown Castle     2845           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights
# 0    Kensington  40.64749  -73.97237     Private room    149               1  \
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
#
#    number_of_reviews reviews_per_month  calculated_host_listings_count
# 0                  9              0.21                               6  \
# 1                 45              0.38                               2
#
#    availability_365
# 0               365
# 1               355

# %%
plt.figure(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='white',
                          width=1920,
                          height=1080
                         ).generate(" ".join(df.name))
plt.imshow(wordcloud)
plt.axis('off')
plt.title("Keywords for property names")

plt.show()

# %% [markdown]
# #### Observation :
# ###### * The location plays a pivotal role in distinguishing listings, with terms like 'Manhattan,' 'Brooklyn,' 'Williamsberg,' and 'Central Park' standing out prominently.
# ###### * The prominence of the phrase 'Private room' signifies its popularity as a favored lodging option in NYC.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ##### * Highly Reviewed Listings:
#         The listing "Room near JFK Queen Bed" stands out with an impressive 629 reviews, followed closely by "Great Bedroom in Manhattan" with 607 reviews, indicating their popularity among travelers.
#
# ##### * Limited Shared Rooms:
#         The scarcity of 'Shared room' listings among the top 10 neighborhoods with the highest listing densities suggests a preference for 'Entire home/apt' and 'Private room' types, highlighting a demand for privacy and convenience.
#
# ##### * Room Type Distribution:
#         The dataset is primarily dominated by two room types: 'Entire home/apt' (53.1%) and 'Private room' (46.7%), with 'Shared room' making up only 2.4% of the listings.
#
# ##### * Popular Destinations:
#         Manhattan and Brooklyn emerge as highly sought-after travel destinations, leading to a higher availability of listings. Bedford-Stuyvesant and Williamsburg are popular in Manhattan, while Harlem is a preferred neighborhood in Brooklyn.
#
# ##### * Price Range Variation:
#         Manhattan boasts the highest price range, with an average of $150 per night, followed by Brooklyn at $90. Queens and Staten Island show similar price distributions, while Bronx offers more budget-friendly options.
#
# ##### * Cost of Living:
#         The higher prices in Manhattan reflect its status as one of the world's most expensive places to live. In contrast, Bronx offers relatively more affordable accommodations, indicating a potential variance in living standards.
